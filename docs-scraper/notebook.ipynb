# %%
import os
import requests
from urllib.parse import urljoin, urlparse
from bs4 import BeautifulSoup
import html2text
import hashlib
import shutil
import readability

# Set of visited URLs to prevent infinite recursion
visited_urls = set()

def download_page(url):
    """
    Downloads the content of a web page from the given URL.

    Args:
        url (str): The URL of the web page to download.

    Returns:
        str: The content of the web page as a string, or None if there was an error.

    Raises:
        requests.RequestException: If there was an error while downloading the web page.
    """
    try:
        response = requests.get(url)
        response.raise_for_status()  # Raises an error for bad status codes
        return response.text
    except requests.RequestException as e:
        print(f"Error downloading {url}: {e}")
        return None

def extract_urls(html, base_url, ignored_extensions = ['.txt', '.pdf', '.docx']):
    """
    Extracts all URLs from the given HTML content, resolving relative URLs and ignoring hash fragments.

    Args:
        html (str): The HTML content to extract URLs from.
        base_url (str): The base URL used to resolve relative URLs.

    Returns:
        set: A set of URLs extracted from the HTML content.
    """
    soup = BeautifulSoup(html, 'html.parser')
    urls = set()
    for link in soup.find_all('a', href=True):
        href = link['href']
        # Resolve relative URLs and filter by hash fragment
        full_url = urljoin(base_url, href.split('#', 1)[0])
        # Ignore URLs ending with specific file extensions
        if any(full_url.endswith(ext) for ext in ignored_extensions):
            continue
        if urlparse(full_url).netloc == urlparse(base_url).netloc:
            urls.add(full_url)
    return urls



def html_to_markdown(html):
    """
    Converts HTML content to Markdown format.

    Parameters:
    html (str): The HTML content to be converted.

    Returns:
    str: The Markdown representation of the HTML content.
    """
    # Using readability to extract the main content
    document = readability.Document(html)
    summary = document.summary()

    converter = html2text.HTML2Text()
    converter.ignore_links = False
    return converter.handle(summary)

def save_markdown(markdown, folder, filename):
    if not os.path.exists(folder):
        os.makedirs(folder)
    filepath = os.path.join(folder, filename)
    with open(filepath, 'w', encoding='utf-8') as f:
        f.write(markdown)


def generate_filename(url, base_url):
    """
    Generate a filename based on the given URL and base URL.

    Args:
        url (str): The URL from which the filename will be generated.
        base_url (str): The base URL used to remove the common path from the URL.

    Returns:
        str: The generated filename.

    """
    # Parse the URLs
    parsed_url = urlparse(url)
    parsed_base_url = urlparse(base_url)

    # Remove the base URL path to get the unique part of the path
    base_path = parsed_base_url.path.strip('/')
    unique_path = parsed_url.path.strip('/')

    # If the base_path is not empty, remove it from the start of unique_path
    if base_path and unique_path.startswith(base_path):
        unique_path = unique_path[len(base_path):].strip('/')

    # Split the path into segments and join them with hyphens
    if unique_path:
        filename = unique_path.replace('/', '-').lower() + ".md"
    else:
        filename = "index.md"
    return filename


def scrape_site(url, base_url, base_folder=''):
    """
    Scrapes a website recursively, saving the content as markdown files.

    Args:
        url (str): The URL of the website to scrape.
        base_url (str): The base URL of the website.
        base_folder (str, optional): The base folder to save the markdown files. Defaults to ''.

    Returns:
        None
    """
    # Ensure the URL starts with the base URL
    if not url.startswith(base_url):
        return

    if url in visited_urls or urlparse(url).netloc != urlparse(base_url).netloc:
        return
    visited_urls.add(url)

    print(f"Scraping {url}")
    html = download_page(url)
    if html:
        markdown = html_to_markdown(html)
        filename = generate_filename(url, base_url)
        folder = os.path.join(base_folder, urlparse(base_url).netloc)
        save_markdown(markdown, folder, filename)

        for link in extract_urls(html, url):
            scrape_site(link, base_url, base_folder)



def clean_directory(folder):
    """
    Deletes all files and folders in the specified directory.

    Args:
        folder (str): The path to the directory to be cleaned.

    Raises:
        OSError: If there is an error while deleting files or folders.

    """
    if os.path.exists(folder):
        for filename in os.listdir(folder):
            file_path = os.path.join(folder, filename)
            try:
                if os.path.isfile(file_path) or os.path.islink(file_path):
                    os.unlink(file_path)
                elif os.path.isdir(file_path):
                    shutil.rmtree(file_path)
            except Exception as e:
                print(f'Failed to delete {file_path}. Reason: {e}')

# Example usage

base_url = 'https://vectorbt.pro/'  # Change this URL to your target
url_secret = os.getenv('VBT_PRO_SECRET_URL') # '5af3d00f'
print(f"Secret URL: {url_secret}")
start_url = f'{base_url}{url_secret}/'  # Change this URL to your target
base_folder = 'output'

clean_directory(base_folder)
scrape_site(start_url, start_url, base_folder)
print("Scraping complete.")
# Out:
# Secret URL: pvt_5af3d00f
# Scraping https://vectorbt.pro/pvt_5af3d00f/
# Scraping https://vectorbt.pro/pvt_5af3d00f/api/portfolio/base/
# Scraping https://vectorbt.pro/pvt_5af3d00f/tutorials/superfast-supertrend/
# Scraping https://vectorbt.pro/pvt_5af3d00f/documentation/fundamentals/
# Scraping https://vectorbt.pro/pvt_5af3d00f/features/indicators/
# Scraping https://vectorbt.pro/pvt_5af3d00f/tutorials/cross-validation/applications/
# Scraping https://vectorbt.pro/pvt_5af3d00f/api/base/reshaping/
# Scraping https://vectorbt.pro/pvt_5af3d00f/api/generic/price_records/
# Scraping https://vectorbt.pro/pvt_5af3d00f/api/utils/path_/
# Scraping https://vectorbt.pro/pvt_5af3d00f/api/utils/datetime_/
# Scraping https://vectorbt.pro/pvt_5af3d00f/features/optimization/
# Scraping https://vectorbt.pro/pvt_5af3d00f/tutorials/cross-validation
# Scraping https://vectorbt.pro/pvt_5af3d00f/patterns-and-projections/projections/
# Error downloading https://vectorbt.pro/pvt_5af3d00f/patterns-and-projections/projections/: 404 Client Error: Not Found for url: https://vectorbt.pro/pvt_5af3d00f/patterns-and-projections/projections/
# Scraping https://vectorbt.pro/pvt_5af3d00f/api/data/base/
# Scraping https://vectorbt.pro/pvt_5af3d00f/api/data/custom/feather/
# Scraping https://vectorbt.pro/pvt_5af3d00f/api/data/custom/bento/
# Scraping https://vectorbt.pro/pvt_5af3d00f/api/data/custom/file/
# Scraping https://vectorbt.pro/pvt_5af3d00f/api/signals/nb/
# Scraping https://vectorbt.pro/pvt_5af3d00f/api/utils/enum_/
# Scraping https://vectorbt.pro/pvt_5af3d00f/api/portfolio/chunking/
# Scraping https://vectorbt.pro/pvt_5af3d00f/api/base/decorators/
# Scraping https://vectorbt.pro/pvt_5af3d00f/api/utils/search/
# Scraping https://vectorbt.pro/pvt_5af3d00f/api/base/preparing/
# Scraping https://vectorbt.pro/pvt_5af3d00f/api/_opt_deps/
# Scraping https://vectorbt.pro/pvt_5af3d00f/api/generic/drawdowns/
# Scraping https://vectorbt.pro/pvt_5af3d00f/features/overview/
# Scraping https://vectorbt.pro/pvt_5af3d00f/tutorials/mtf-analysis/alignment/
# Scraping https://vectorbt.pro/pvt_5af3d00f/documentation/data/synthetic/
# Scraping https://vectorbt.pro/pvt_5af3d00f/documentation/portfolio/from-signals/
# Scraping https://vectorbt.pro/pvt_5af3d00f/cookbook/discovery/
# Scraping https://vectorbt.pro/pvt_5af3d00f/api/data/decorators/
# Scraping https://vectorbt.pro/pvt_5af3d00f/cookbook/benchmarking/
# Scraping https://vectorbt.pro/pvt_5af3d00f/api/messaging/
# Scraping https://vectorbt.pro/pvt_5af3d00f/tutorials/stop-signals/
# Scraping https://vectorbt.pro/pvt_5af3d00f/api/generic/plotting/
# Scraping https://vectorbt.pro/pvt_5af3d00f/api/generic/stats_builder/
# Scraping https://vectorbt.pro/pvt_5af3d00f/api/utils/params/
# Scraping https://vectorbt.pro/pvt_5af3d00f/cookbook/compilation/
# Scraping https://vectorbt.pro/pvt_5af3d00f/api/registries/jit_registry/
# Scraping https://vectorbt.pro/pvt_5af3d00f/api/px/accessors/
# Scraping https://vectorbt.pro/pvt_5af3d00f/api/utils/tagging/
# Scraping https://vectorbt.pro/pvt_5af3d00f/api/utils/decorators/
# Scraping https://vectorbt.pro/pvt_5af3d00f/api/utils/eval_/
# Scraping https://vectorbt.pro/pvt_5af3d00f/api/utils/selection/
# Scraping https://vectorbt.pro/pvt_5af3d00f/api/records/chunking/
# Scraping https://vectorbt.pro/pvt_5af3d00f/documentation/indicators/development/
# Scraping https://vectorbt.pro/pvt_5af3d00f/tutorials/signal-development/pre-analysis/
# Scraping https://vectorbt.pro/pvt_5af3d00f/api/portfolio/trades/
# Scraping https://vectorbt.pro/pvt_5af3d00f/api/portfolio/nb/records/
# Scraping https://vectorbt.pro/pvt_5af3d00f/api/portfolio/nb/core/
# Scraping https://vectorbt.pro/pvt_5af3d00f/api/portfolio/nb/iter_/
# Scraping https://vectorbt.pro/pvt_5af3d00f/api/returns/enums/
# Scraping https://vectorbt.pro/pvt_5af3d00f/api/records/
# Scraping https://vectorbt.pro/pvt_5af3d00f/api/ohlcv/nb/
# Scraping https://vectorbt.pro/pvt_5af3d00f/api/utils/figure/
# Scraping https://vectorbt.pro/pvt_5af3d00f/api/utils/pbar/
# Scraping https://vectorbt.pro/pvt_5af3d00f/api/portfolio/enums/
# Scraping https://vectorbt.pro/pvt_5af3d00f/api/base/merging/
# Scraping https://vectorbt.pro/pvt_5af3d00f/api/returns/nb/
# Scraping https://vectorbt.pro/pvt_5af3d00f/api/records/nb/
# Scraping https://vectorbt.pro/pvt_5af3d00f/getting-started/release-notes/2021/
# Scraping https://vectorbt.pro/pvt_5af3d00f/api/data/custom/binance/
# Scraping https://vectorbt.pro/pvt_5af3d00f/api/data/custom/alpaca/
# Scraping https://vectorbt.pro/pvt_5af3d00f/api/labels/enums/
# Scraping https://vectorbt.pro/pvt_5af3d00f/api/utils/
# Scraping https://vectorbt.pro/pvt_5af3d00f/api/signals/generators/stx/
# Scraping https://vectorbt.pro/pvt_5af3d00f/api/signals/generators/stcx/
# Scraping https://vectorbt.pro/pvt_5af3d00f/api/signals/generators/ohlcstx/
# Scraping https://vectorbt.pro/pvt_5af3d00f/api/signals/generators/rprobcx/
# Scraping https://vectorbt.pro/pvt_5af3d00f/api/signals/
# Scraping https://vectorbt.pro/pvt_5af3d00f/api/generic/enums/
# Scraping https://vectorbt.pro/pvt_5af3d00f/api/generic/nb/rolling/
# Scraping https://vectorbt.pro/pvt_5af3d00f/api/generic/nb/patterns/
# Scraping https://vectorbt.pro/pvt_5af3d00f/documentation/indicators/analysis/
# Scraping https://vectorbt.pro/pvt_5af3d00f/tutorials/superfast-supertrend/multithreading/
# Scraping https://vectorbt.pro/pvt_5af3d00f/tutorials/mtf-analysis/
# Scraping https://vectorbt.pro/pvt_5af3d00f/api/base/resampling/base/
# Scraping https://vectorbt.pro/pvt_5af3d00f/api/accessors/
# Scraping https://vectorbt.pro/pvt_5af3d00f/cookbook/arrays/
# Scraping https://vectorbt.pro/pvt_5af3d00f/api/signals/accessors/
# Scraping https://vectorbt.pro/pvt_5af3d00f/api/indicators/
# Scraping https://vectorbt.pro/pvt_5af3d00f/api/utils/array_/
# Scraping https://vectorbt.pro/pvt_5af3d00f/cookbook/caching/
# Scraping https://vectorbt.pro/pvt_5af3d00f/api/generic/analyzable/
# Scraping https://vectorbt.pro/pvt_5af3d00f/api/generic/splitting/base/
# Scraping https://vectorbt.pro/pvt_5af3d00f/api/generic/splitting/purged/
# Scraping https://vectorbt.pro/pvt_5af3d00f/api/utils/random_/
# Scraping https://vectorbt.pro/pvt_5af3d00f/api/base/grouping/
# Scraping https://vectorbt.pro/pvt_5af3d00f/api/base/grouping/nb/
# Scraping https://vectorbt.pro/pvt_5af3d00f/getting-started/installation/
# Scraping https://vectorbt.pro/pvt_5af3d00f/api/ohlcv/accessors/
# Scraping https://vectorbt.pro/pvt_5af3d00f/cookbook/signals/
# Scraping https://vectorbt.pro/pvt_5af3d00f/api/data/nb/
# Scraping https://vectorbt.pro/pvt_5af3d00f/api/portfolio/call_seq/
# Scraping https://vectorbt.pro/pvt_5af3d00f/tutorials/more-tutorials/
# Scraping https://vectorbt.pro/pvt_5af3d00f/getting-started/release-notes/2023/
# Scraping https://vectorbt.pro/pvt_5af3d00f/api/portfolio/nb/from_signals/
# Scraping https://vectorbt.pro/pvt_5af3d00f/api/portfolio/nb/analysis/
# Scraping https://vectorbt.pro/pvt_5af3d00f/api/portfolio/nb/from_orders/
# Scraping https://vectorbt.pro/pvt_5af3d00f/tutorials/to-be-continued/
# Scraping https://vectorbt.pro/pvt_5af3d00f/api/utils/template/
# Scraping https://vectorbt.pro/pvt_5af3d00f/documentation/data/scheduling/
# Scraping https://vectorbt.pro/pvt_5af3d00f/api/registries/ca_registry/
# Scraping https://vectorbt.pro/pvt_5af3d00f/features
# Scraping https://vectorbt.pro/pvt_5af3d00f/documentation/data/local/
# Scraping https://vectorbt.pro/pvt_5af3d00f/api/data/custom/parquet/
# Scraping https://vectorbt.pro/pvt_5af3d00f/api/data/custom/gbm/
# Scraping https://vectorbt.pro/pvt_5af3d00f/api/data/custom/yf/
# Scraping https://vectorbt.pro/pvt_5af3d00f/terms/remarks/
# Scraping https://vectorbt.pro/pvt_5af3d00f/cookbook/portfolio/
# Scraping https://vectorbt.pro/pvt_5af3d00f/terms/terms-of-use/
# Scraping https://vectorbt.pro/pvt_5af3d00f/api/indicators/expr/
# Scraping https://vectorbt.pro/pvt_5af3d00f/api/px/
# Scraping https://vectorbt.pro/pvt_5af3d00f/api/portfolio/pfopt/records/
# Scraping https://vectorbt.pro/pvt_5af3d00f/api/portfolio/pfopt/base/
# Scraping https://vectorbt.pro/pvt_5af3d00f/api/portfolio/pfopt/nb/
# Scraping https://vectorbt.pro/pvt_5af3d00f/api/data/updater/
# Scraping https://vectorbt.pro/pvt_5af3d00f/api/generic/accessors/
# Scraping https://vectorbt.pro/pvt_5af3d00f/api/labels/
# Scraping https://vectorbt.pro/pvt_5af3d00f/api/indicators/custom/vwap/
# Scraping https://vectorbt.pro/pvt_5af3d00f/api/indicators/custom/macd/
# Scraping https://vectorbt.pro/pvt_5af3d00f/api/indicators/custom/bbands/
# Scraping https://vectorbt.pro/pvt_5af3d00f/api/indicators/custom/ma/
# Scraping https://vectorbt.pro/pvt_5af3d00f/api/indicators/custom/sigdet/
# Scraping https://vectorbt.pro/pvt_5af3d00f/api/indicators/custom/msd/
# Scraping https://vectorbt.pro/pvt_5af3d00f/api/registries/ch_registry/
# Scraping https://vectorbt.pro/pvt_5af3d00f/tutorials/mtf-analysis/aggregation/
# Scraping https://vectorbt.pro/pvt_5af3d00f/api/indicators/enums/
# Scraping https://vectorbt.pro/pvt_5af3d00f/api/base/chunking/
# Scraping https://vectorbt.pro/pvt_5af3d00f/tutorials/cross-validation/splitter/
# Scraping https://vectorbt.pro/pvt_5af3d00f/documentation/portfolio/
# Scraping https://vectorbt.pro/pvt_5af3d00f/documentation/data/remote/
# Scraping https://vectorbt.pro/pvt_5af3d00f/api/labels/generators/
# Scraping https://vectorbt.pro/pvt_5af3d00f/api/labels/generators/pivotlb/
# Scraping https://vectorbt.pro/pvt_5af3d00f/api/labels/generators/fmean/
# Scraping https://vectorbt.pro/pvt_5af3d00f/api/labels/generators/fstd/
# Scraping https://vectorbt.pro/pvt_5af3d00f/api/labels/generators/trendlb/
# Scraping https://vectorbt.pro/pvt_5af3d00f/api/labels/generators/fmin/
# Scraping https://vectorbt.pro/pvt_5af3d00f/api/labels/generators/fmax/
# Scraping https://vectorbt.pro/pvt_5af3d00f/api/utils/chunking/
# Scraping https://vectorbt.pro/pvt_5af3d00f/api/utils/formatting/
# Scraping https://vectorbt.pro/pvt_5af3d00f/api/utils/annotations/
# Scraping https://vectorbt.pro/pvt_5af3d00f/api/utils/profiling/
# Scraping https://vectorbt.pro/pvt_5af3d00f/cookbook/indexing/
# Scraping https://vectorbt.pro/pvt_5af3d00f/api/base/wrapping/
# Scraping https://vectorbt.pro/pvt_5af3d00f/getting-started/release-notes/2022/
# Scraping https://vectorbt.pro/pvt_5af3d00f/tutorials/basic-rsi
# Scraping https://vectorbt.pro/pvt_5af3d00f/superfast-supertrend/pipelines/
# Error downloading https://vectorbt.pro/pvt_5af3d00f/superfast-supertrend/pipelines/: 404 Client Error: Not Found for url: https://vectorbt.pro/pvt_5af3d00f/superfast-supertrend/pipelines/
# Scraping https://vectorbt.pro/pvt_5af3d00f/superfast-supertrend/multithreading/
# Error downloading https://vectorbt.pro/pvt_5af3d00f/superfast-supertrend/multithreading/: 404 Client Error: Not Found for url: https://vectorbt.pro/pvt_5af3d00f/superfast-supertrend/multithreading/
# Scraping https://vectorbt.pro/pvt_5af3d00f/mtf-analysis/
# Error downloading https://vectorbt.pro/pvt_5af3d00f/mtf-analysis/: 404 Client Error: Not Found for url: https://vectorbt.pro/pvt_5af3d00f/mtf-analysis/
# Scraping https://vectorbt.pro/pvt_5af3d00f/superfast-supertrend/streaming/
# Error downloading https://vectorbt.pro/pvt_5af3d00f/superfast-supertrend/streaming/: 404 Client Error: Not Found for url: https://vectorbt.pro/pvt_5af3d00f/superfast-supertrend/streaming/
# Scraping https://vectorbt.pro/pvt_5af3d00f/signal-development/generation/
# Error downloading https://vectorbt.pro/pvt_5af3d00f/signal-development/generation/: 404 Client Error: Not Found for url: https://vectorbt.pro/pvt_5af3d00f/signal-development/generation/
# Scraping https://vectorbt.pro/pvt_5af3d00f/patterns-and-projections/patterns/
# Error downloading https://vectorbt.pro/pvt_5af3d00f/patterns-and-projections/patterns/: 404 Client Error: Not Found for url: https://vectorbt.pro/pvt_5af3d00f/patterns-and-projections/patterns/
# Scraping https://vectorbt.pro/pvt_5af3d00f/cross-validation/
# Error downloading https://vectorbt.pro/pvt_5af3d00f/cross-validation/: 404 Client Error: Not Found for url: https://vectorbt.pro/pvt_5af3d00f/cross-validation/
# Scraping https://vectorbt.pro/pvt_5af3d00f/mtf-analysis/alignment/
# Error downloading https://vectorbt.pro/pvt_5af3d00f/mtf-analysis/alignment/: 404 Client Error: Not Found for url: https://vectorbt.pro/pvt_5af3d00f/mtf-analysis/alignment/
# Scraping https://vectorbt.pro/pvt_5af3d00f/signal-development/pre-analysis/
# Error downloading https://vectorbt.pro/pvt_5af3d00f/signal-development/pre-analysis/: 404 Client Error: Not Found for url: https://vectorbt.pro/pvt_5af3d00f/signal-development/pre-analysis/
# Scraping https://vectorbt.pro/pvt_5af3d00f/pairs-trading/
# Error downloading https://vectorbt.pro/pvt_5af3d00f/pairs-trading/: 404 Client Error: Not Found for url: https://vectorbt.pro/pvt_5af3d00f/pairs-trading/
# Scraping https://vectorbt.pro/pvt_5af3d00f/cross-validation/applications/
# Error downloading https://vectorbt.pro/pvt_5af3d00f/cross-validation/applications/: 404 Client Error: Not Found for url: https://vectorbt.pro/pvt_5af3d00f/cross-validation/applications/
# Scraping https://vectorbt.pro/pvt_5af3d00f/portfolio-optimization/
# Error downloading https://vectorbt.pro/pvt_5af3d00f/portfolio-optimization/: 404 Client Error: Not Found for url: https://vectorbt.pro/pvt_5af3d00f/portfolio-optimization/
# Scraping https://vectorbt.pro/pvt_5af3d00f/api/generic/ranges/
# Scraping https://vectorbt.pro/pvt_5af3d00f/tutorials/superfast-supertrend/streaming/
# Scraping https://vectorbt.pro/pvt_5af3d00f/api/messaging/telegram/
# Scraping https://vectorbt.pro/pvt_5af3d00f/cookbook/configuration/
# Scraping https://vectorbt.pro/pvt_5af3d00f/api/generic/nb/
# Scraping https://vectorbt.pro/pvt_5af3d00f/api/generic/nb/records/
# Scraping https://vectorbt.pro/pvt_5af3d00f/getting-started/release-notes/
# Scraping https://vectorbt.pro/pvt_5af3d00f/api/portfolio/nb/ctx_helpers/
# Scraping https://vectorbt.pro/pvt_5af3d00f/api/utils/attr_/
# Scraping https://vectorbt.pro/pvt_5af3d00f/tutorials/superfast-supertrend/pipelines/
# Scraping https://vectorbt.pro/pvt_5af3d00f/api/records/mapped_array/
# Scraping https://vectorbt.pro/pvt_5af3d00f/api/utils/config/
# Scraping https://vectorbt.pro/pvt_5af3d00f/api/_settings/
# Scraping https://vectorbt.pro/pvt_5af3d00f/cookbook/persistence/
# Scraping https://vectorbt.pro/pvt_5af3d00f/tutorials/cross-validation/
# Scraping https://vectorbt.pro/pvt_5af3d00f/api/portfolio/decorators/
# Scraping https://vectorbt.pro/pvt_5af3d00f/cookbook/overview/
# Scraping https://vectorbt.pro/pvt_5af3d00f/api/portfolio/nb/
# Scraping https://vectorbt.pro/pvt_5af3d00f/api/portfolio/logs/
# Scraping https://vectorbt.pro/pvt_5af3d00f/api/generic/decorators/
# Scraping https://vectorbt.pro/pvt_5af3d00f/api/base/accessors/
# Scraping https://vectorbt.pro/pvt_5af3d00f/api/
# Scraping https://vectorbt.pro/pvt_5af3d00f/api/indicators/custom/
# Scraping https://vectorbt.pro/pvt_5af3d00f/api/indicators/custom/pivotinfo/
# Scraping https://vectorbt.pro/pvt_5af3d00f/api/indicators/custom/atr/
# Scraping https://vectorbt.pro/pvt_5af3d00f/api/generic/splitting/
# Scraping https://vectorbt.pro/pvt_5af3d00f/api/generic/splitting/decorators/
# Scraping https://vectorbt.pro/pvt_5af3d00f/api/generic/splitting/nb/
# Scraping https://vectorbt.pro/pvt_5af3d00f/api/generic/splitting/sklearn_/
# Scraping https://vectorbt.pro/pvt_5af3d00f/api/portfolio/orders/
# Scraping https://vectorbt.pro/pvt_5af3d00f/api/signals/generators/
# Scraping https://vectorbt.pro/pvt_5af3d00f/api/signals/generators/rprob/
# Scraping https://vectorbt.pro/pvt_5af3d00f/api/signals/generators/rprobnx/
# Scraping https://vectorbt.pro/pvt_5af3d00f/api/signals/generators/randx/
# Scraping https://vectorbt.pro/pvt_5af3d00f/api/signals/generators/ohlcstcx/
# Scraping https://vectorbt.pro/pvt_5af3d00f/api/utils/schedule_/
# Scraping https://vectorbt.pro/pvt_5af3d00f/api/utils/hashing/
# Scraping https://vectorbt.pro/pvt_5af3d00f/features/portfolio/
# Scraping https://vectorbt.pro/pvt_5af3d00f/features/productivity/
# Scraping https://vectorbt.pro/pvt_5af3d00f/tutorials/mtf-analysis
# Scraping https://vectorbt.pro/pvt_5af3d00f/tutorials/alignment/
# Error downloading https://vectorbt.pro/pvt_5af3d00f/tutorials/alignment/: 404 Client Error: Not Found for url: https://vectorbt.pro/pvt_5af3d00f/tutorials/alignment/
# Scraping https://vectorbt.pro/pvt_5af3d00f/tutorials/aggregation/
# Error downloading https://vectorbt.pro/pvt_5af3d00f/tutorials/aggregation/: 404 Client Error: Not Found for url: https://vectorbt.pro/pvt_5af3d00f/tutorials/aggregation/
# Scraping https://vectorbt.pro/pvt_5af3d00f/api/data/custom/hdf/
# Scraping https://vectorbt.pro/pvt_5af3d00f/api/data/custom/local/
# Scraping https://vectorbt.pro/pvt_5af3d00f/api/data/custom/av/
# Scraping https://vectorbt.pro/pvt_5af3d00f/api/data/custom/ccxt/
# Scraping https://vectorbt.pro/pvt_5af3d00f/api/data/custom/db/
# Scraping https://vectorbt.pro/pvt_5af3d00f/api/data/custom/random/
# Scraping https://vectorbt.pro/pvt_5af3d00f/api/base/combining/
# Scraping https://vectorbt.pro/pvt_5af3d00f/api/utils/execution/
# Scraping https://vectorbt.pro/pvt_5af3d00f/api/utils/image_/
# Scraping https://vectorbt.pro/pvt_5af3d00f/api/base/resampling/
# Scraping https://vectorbt.pro/pvt_5af3d00f/api/base/resampling/nb/
# Scraping https://vectorbt.pro/pvt_5af3d00f/documentation/portfolio/from-orders/
# Scraping https://vectorbt.pro/pvt_5af3d00f/api/returns/qs_adapter/
# Scraping https://vectorbt.pro/pvt_5af3d00f/tutorials/portfolio-optimization/integrations/
# Scraping https://vectorbt.pro/pvt_5af3d00f/api/base/indexes/
# Scraping https://vectorbt.pro/pvt_5af3d00f/api/utils/checks/
# Scraping https://vectorbt.pro/pvt_5af3d00f/api/generic/
# Scraping https://vectorbt.pro/pvt_5af3d00f/tutorials/portfolio-optimization/
# Scraping https://vectorbt.pro/pvt_5af3d00f/api/utils/mapping/
# Scraping https://vectorbt.pro/pvt_5af3d00f/api/returns/
# Scraping https://vectorbt.pro/pvt_5af3d00f/api/utils/chaining/
# Scraping https://vectorbt.pro/pvt_5af3d00f/tutorials/pairs-trading/
# Scraping https://vectorbt.pro/pvt_5af3d00f/tutorials/patterns-and-projections/projections/
# Scraping https://vectorbt.pro/pvt_5af3d00f/api/signals/factory/
# Scraping https://vectorbt.pro/pvt_5af3d00f/tutorials/portfolio-optimization/dynamic/
# Scraping https://vectorbt.pro/pvt_5af3d00f/api/ohlcv/
# Scraping https://vectorbt.pro/pvt_5af3d00f/api/portfolio/
# Scraping https://vectorbt.pro/pvt_5af3d00f/cookbook/indicators/
# Scraping https://vectorbt.pro/pvt_5af3d00f/documentation/data/
# Scraping https://vectorbt.pro/pvt_5af3d00f/api/data/custom/csv/
# Scraping https://vectorbt.pro/pvt_5af3d00f/api/data/custom/remote/
# Scraping https://vectorbt.pro/pvt_5af3d00f/api/data/custom/polygon/
# Scraping https://vectorbt.pro/pvt_5af3d00f/api/data/custom/duckdb/
# Scraping https://vectorbt.pro/pvt_5af3d00f/api/data/custom/ndl/
# Scraping https://vectorbt.pro/pvt_5af3d00f/api/data/custom/sql/
# Scraping https://vectorbt.pro/pvt_5af3d00f/api/base/flex_indexing/
# Scraping https://vectorbt.pro/pvt_5af3d00f/api/generic/plots_builder/
# Scraping https://vectorbt.pro/pvt_5af3d00f/api/records/base/
# Scraping https://vectorbt.pro/pvt_5af3d00f/api/returns/accessors/
# Scraping https://vectorbt.pro/pvt_5af3d00f/api/data/
# Scraping https://vectorbt.pro/pvt_5af3d00f/api/utils/pickling/
# Scraping https://vectorbt.pro/pvt_5af3d00f/api/portfolio/preparing/
# Scraping https://vectorbt.pro/pvt_5af3d00f/tutorials/patterns-and-projections/patterns/
# Scraping https://vectorbt.pro/pvt_5af3d00f/tutorials/signal-development
# Scraping https://vectorbt.pro/pvt_5af3d00f/api/utils/requests_/
# Scraping https://vectorbt.pro/pvt_5af3d00f/features/data/
# Scraping https://vectorbt.pro/pvt_5af3d00f/cookbook/plotting/
# Scraping https://vectorbt.pro/pvt_5af3d00f/tutorials/basic-rsi/
# Scraping https://vectorbt.pro/pvt_5af3d00f/api/indicators/custom/rsi/
# Scraping https://vectorbt.pro/pvt_5af3d00f/api/indicators/custom/adx/
# Scraping https://vectorbt.pro/pvt_5af3d00f/api/indicators/custom/supertrend/
# Scraping https://vectorbt.pro/pvt_5af3d00f/api/indicators/custom/obv/
# Scraping https://vectorbt.pro/pvt_5af3d00f/api/records/decorators/
# Scraping https://vectorbt.pro/pvt_5af3d00f/api/utils/cutting/
# Scraping https://vectorbt.pro/pvt_5af3d00f/cookbook/optimization/
# Scraping https://vectorbt.pro/pvt_5af3d00f/tutorials/signal-development/generation/
# Scraping https://vectorbt.pro/pvt_5af3d00f/api/generic/nb/apply_reduce/
# Scraping https://vectorbt.pro/pvt_5af3d00f/api/generic/nb/iter_/
# Scraping https://vectorbt.pro/pvt_5af3d00f/api/indicators/factory/
# Scraping https://vectorbt.pro/pvt_5af3d00f/api/signals/generators/randnx/
# Scraping https://vectorbt.pro/pvt_5af3d00f/api/signals/generators/rand/
# Scraping https://vectorbt.pro/pvt_5af3d00f/api/indicators/nb/
# Scraping https://vectorbt.pro/pvt_5af3d00f/api/utils/colors/
# Scraping https://vectorbt.pro/pvt_5af3d00f/api/data/custom/
# Scraping https://vectorbt.pro/pvt_5af3d00f/api/data/custom/gbm_ohlc/
# Scraping https://vectorbt.pro/pvt_5af3d00f/api/data/custom/custom/
# Scraping https://vectorbt.pro/pvt_5af3d00f/api/data/custom/random_ohlc/
# Scraping https://vectorbt.pro/pvt_5af3d00f/api/utils/math_/
# Scraping https://vectorbt.pro/pvt_5af3d00f/api/utils/caching/
# Scraping https://vectorbt.pro/pvt_5af3d00f/api/data/saver/
# Scraping https://vectorbt.pro/pvt_5af3d00f/features/analysis/
# Scraping https://vectorbt.pro/pvt_5af3d00f/tutorials/patterns-and-projections
# Scraping https://vectorbt.pro/pvt_5af3d00f/api/utils/parsing/
# Scraping https://vectorbt.pro/pvt_5af3d00f/api/utils/merging/
# Scraping https://vectorbt.pro/pvt_5af3d00f/documentation/building-blocks/
# Scraping https://vectorbt.pro/pvt_5af3d00f/terms/software-license/
# Scraping https://vectorbt.pro/pvt_5af3d00f/api/utils/jitting/
# Scraping https://vectorbt.pro/pvt_5af3d00f/api/base/indexing/
# Scraping https://vectorbt.pro/pvt_5af3d00f/api/indicators/configs/
# Scraping https://vectorbt.pro/pvt_5af3d00f/documentation/indicators/parsers/
# Scraping https://vectorbt.pro/pvt_5af3d00f/api/generic/nb/base/
# Scraping https://vectorbt.pro/pvt_5af3d00f/documentation/to-be-continued/
# Scraping https://vectorbt.pro/pvt_5af3d00f/api/portfolio/pfopt/
# Scraping https://vectorbt.pro/pvt_5af3d00f/api/utils/magic_decorators/
# Scraping https://vectorbt.pro/pvt_5af3d00f/api/records/col_mapper/
# Scraping https://vectorbt.pro/pvt_5af3d00f/api/registries/
# Scraping https://vectorbt.pro/pvt_5af3d00f/api/utils/module_/
# Scraping https://vectorbt.pro/pvt_5af3d00f/api/utils/datetime_nb/
# Scraping https://vectorbt.pro/pvt_5af3d00f/cookbook/data/
# Scraping https://vectorbt.pro/pvt_5af3d00f/api/labels/nb/
# Scraping https://vectorbt.pro/pvt_5af3d00f/api/base/
# Scraping https://vectorbt.pro/pvt_5af3d00f/api/indicators/talib_/
# Scraping https://vectorbt.pro/pvt_5af3d00f/cookbook/cross-validation/
# Scraping https://vectorbt.pro/pvt_5af3d00f/documentation/indicators/
# Scraping https://vectorbt.pro/pvt_5af3d00f/documentation/building-blocks
# Scraping https://vectorbt.pro/pvt_5af3d00f/portfolio/from-orders/
# Error downloading https://vectorbt.pro/pvt_5af3d00f/portfolio/from-orders/: 404 Client Error: Not Found for url: https://vectorbt.pro/pvt_5af3d00f/portfolio/from-orders/
# Scraping https://vectorbt.pro/pvt_5af3d00f/documentation/
# Scraping https://vectorbt.pro/pvt_5af3d00f/portfolio/from-signals/
# Error downloading https://vectorbt.pro/pvt_5af3d00f/portfolio/from-signals/: 404 Client Error: Not Found for url: https://vectorbt.pro/pvt_5af3d00f/portfolio/from-signals/
# Scraping https://vectorbt.pro/pvt_5af3d00f/portfolio/
# Error downloading https://vectorbt.pro/pvt_5af3d00f/portfolio/: 404 Client Error: Not Found for url: https://vectorbt.pro/pvt_5af3d00f/portfolio/
# Scraping https://vectorbt.pro/pvt_5af3d00f/indicators/analysis/
# Error downloading https://vectorbt.pro/pvt_5af3d00f/indicators/analysis/: 404 Client Error: Not Found for url: https://vectorbt.pro/pvt_5af3d00f/indicators/analysis/
# Scraping https://vectorbt.pro/pvt_5af3d00f/fundamentals/
# Error downloading https://vectorbt.pro/pvt_5af3d00f/fundamentals/: 404 Client Error: Not Found for url: https://vectorbt.pro/pvt_5af3d00f/fundamentals/
# Scraping https://vectorbt.pro/pvt_5af3d00f/to-be-continued/
# Error downloading https://vectorbt.pro/pvt_5af3d00f/to-be-continued/: 404 Client Error: Not Found for url: https://vectorbt.pro/pvt_5af3d00f/to-be-continued/
# Scraping https://vectorbt.pro/pvt_5af3d00f/data/synthetic/
# Error downloading https://vectorbt.pro/pvt_5af3d00f/data/synthetic/: 404 Client Error: Not Found for url: https://vectorbt.pro/pvt_5af3d00f/data/synthetic/
# Scraping https://vectorbt.pro/pvt_5af3d00f/data/remote/
# Error downloading https://vectorbt.pro/pvt_5af3d00f/data/remote/: 404 Client Error: Not Found for url: https://vectorbt.pro/pvt_5af3d00f/data/remote/
# Scraping https://vectorbt.pro/pvt_5af3d00f/indicators/parsers/
# Error downloading https://vectorbt.pro/pvt_5af3d00f/indicators/parsers/: 404 Client Error: Not Found for url: https://vectorbt.pro/pvt_5af3d00f/indicators/parsers/
# Scraping https://vectorbt.pro/pvt_5af3d00f/indicators/
# Error downloading https://vectorbt.pro/pvt_5af3d00f/indicators/: 404 Client Error: Not Found for url: https://vectorbt.pro/pvt_5af3d00f/indicators/
# Scraping https://vectorbt.pro/pvt_5af3d00f/data/scheduling/
# Error downloading https://vectorbt.pro/pvt_5af3d00f/data/scheduling/: 404 Client Error: Not Found for url: https://vectorbt.pro/pvt_5af3d00f/data/scheduling/
# Scraping https://vectorbt.pro/pvt_5af3d00f/indicators/development/
# Error downloading https://vectorbt.pro/pvt_5af3d00f/indicators/development/: 404 Client Error: Not Found for url: https://vectorbt.pro/pvt_5af3d00f/indicators/development/
# Scraping https://vectorbt.pro/pvt_5af3d00f/data/
# Error downloading https://vectorbt.pro/pvt_5af3d00f/data/: 404 Client Error: Not Found for url: https://vectorbt.pro/pvt_5af3d00f/data/
# Scraping https://vectorbt.pro/pvt_5af3d00f/data/local/
# Error downloading https://vectorbt.pro/pvt_5af3d00f/data/local/: 404 Client Error: Not Found for url: https://vectorbt.pro/pvt_5af3d00f/data/local/
# Scraping https://vectorbt.pro/pvt_5af3d00f/features/performance/
# Scraping https://vectorbt.pro/pvt_5af3d00f/api/signals/enums/
# Scraping https://vectorbt.pro/pvt_5af3d00f/api/data/custom/tv/
# Scraping https://vectorbt.pro/pvt_5af3d00f/api/data/custom/synthetic/
# Scraping https://vectorbt.pro/pvt_5af3d00f/api/signals/generators/rprobx/
# Scraping https://vectorbt.pro/pvt_5af3d00f/api/labels/generators/meanlb/
# Scraping https://vectorbt.pro/pvt_5af3d00f/api/labels/generators/bolb/
# Scraping https://vectorbt.pro/pvt_5af3d00f/api/labels/generators/fixlb/
# Scraping https://vectorbt.pro/pvt_5af3d00f/api/indicators/custom/stoch/
# Scraping https://vectorbt.pro/pvt_5af3d00f/api/indicators/custom/ols/
# Scraping https://vectorbt.pro/pvt_5af3d00f/api/indicators/custom/patsim/
# Scraping https://vectorbt.pro/pvt_5af3d00f/api/portfolio/nb/from_order_func/
# Scraping https://vectorbt.pro/pvt_5af3d00f/api/base/grouping/base/
# Scraping https://vectorbt.pro/pvt_5af3d00f/portfolio-optimization/dynamic/
# Error downloading https://vectorbt.pro/pvt_5af3d00f/portfolio-optimization/dynamic/: 404 Client Error: Not Found for url: https://vectorbt.pro/pvt_5af3d00f/portfolio-optimization/dynamic/
# Scraping https://vectorbt.pro/pvt_5af3d00f/portfolio-optimization/integrations/
# Error downloading https://vectorbt.pro/pvt_5af3d00f/portfolio-optimization/integrations/: 404 Client Error: Not Found for url: https://vectorbt.pro/pvt_5af3d00f/portfolio-optimization/integrations/
# Scraping https://vectorbt.pro/pvt_5af3d00f/tutorials/
# Error downloading https://vectorbt.pro/pvt_5af3d00f/tutorials/: 404 Client Error: Not Found for url: https://vectorbt.pro/pvt_5af3d00f/tutorials/
# Scraping https://vectorbt.pro/pvt_5af3d00f/basic-rsi/
# Error downloading https://vectorbt.pro/pvt_5af3d00f/basic-rsi/: 404 Client Error: Not Found for url: https://vectorbt.pro/pvt_5af3d00f/basic-rsi/
# Scraping https://vectorbt.pro/pvt_5af3d00f/cross-validation/splitter/
# Error downloading https://vectorbt.pro/pvt_5af3d00f/cross-validation/splitter/: 404 Client Error: Not Found for url: https://vectorbt.pro/pvt_5af3d00f/cross-validation/splitter/
# Scraping https://vectorbt.pro/pvt_5af3d00f/more-tutorials/
# Error downloading https://vectorbt.pro/pvt_5af3d00f/more-tutorials/: 404 Client Error: Not Found for url: https://vectorbt.pro/pvt_5af3d00f/more-tutorials/
# Scraping https://vectorbt.pro/pvt_5af3d00f/superfast-supertrend/
# Error downloading https://vectorbt.pro/pvt_5af3d00f/superfast-supertrend/: 404 Client Error: Not Found for url: https://vectorbt.pro/pvt_5af3d00f/superfast-supertrend/
# Scraping https://vectorbt.pro/pvt_5af3d00f/stop-signals/
# Error downloading https://vectorbt.pro/pvt_5af3d00f/stop-signals/: 404 Client Error: Not Found for url: https://vectorbt.pro/pvt_5af3d00f/stop-signals/
# Scraping https://vectorbt.pro/pvt_5af3d00f/mtf-analysis/aggregation/
# Error downloading https://vectorbt.pro/pvt_5af3d00f/mtf-analysis/aggregation/: 404 Client Error: Not Found for url: https://vectorbt.pro/pvt_5af3d00f/mtf-analysis/aggregation/
# Scraping https://vectorbt.pro/pvt_5af3d00f/api/indicators/custom/olss/
# Error downloading https://vectorbt.pro/pvt_5af3d00f/api/indicators/custom/olss/: 404 Client Error: Not Found for url: https://vectorbt.pro/pvt_5af3d00f/api/indicators/custom/olss/
# Scraping https://vectorbt.pro/pvt_5af3d00f/tutorials/stop-signals
# Scraping https://vectorbt.pro/pvt_5af3d00f/tutorials/portfolio-optimization
# Scraping https://vectorbt.pro/pvt_5af3d00f/tutorials/dynamic/
# Error downloading https://vectorbt.pro/pvt_5af3d00f/tutorials/dynamic/: 404 Client Error: Not Found for url: https://vectorbt.pro/pvt_5af3d00f/tutorials/dynamic/
# Scraping https://vectorbt.pro/pvt_5af3d00f/tutorials/integrations/
# Error downloading https://vectorbt.pro/pvt_5af3d00f/tutorials/integrations/: 404 Client Error: Not Found for url: https://vectorbt.pro/pvt_5af3d00f/tutorials/integrations/
# Scraping https://vectorbt.pro/pvt_5af3d00f/tutorials/superfast-supertrend
# Scraping https://vectorbt.pro/pvt_5af3d00f/tutorials/multithreading/
# Error downloading https://vectorbt.pro/pvt_5af3d00f/tutorials/multithreading/: 404 Client Error: Not Found for url: https://vectorbt.pro/pvt_5af3d00f/tutorials/multithreading/
# Scraping https://vectorbt.pro/pvt_5af3d00f/tutorials/pipelines/
# Error downloading https://vectorbt.pro/pvt_5af3d00f/tutorials/pipelines/: 404 Client Error: Not Found for url: https://vectorbt.pro/pvt_5af3d00f/tutorials/pipelines/
# Scraping https://vectorbt.pro/pvt_5af3d00f/tutorials/streaming/
# Error downloading https://vectorbt.pro/pvt_5af3d00f/tutorials/streaming/: 404 Client Error: Not Found for url: https://vectorbt.pro/pvt_5af3d00f/tutorials/streaming/
# Scraping https://vectorbt.pro/pvt_5af3d00f/api/indicators/custom/zigzag/
# Error downloading https://vectorbt.pro/pvt_5af3d00f/api/indicators/custom/zigzag/: 404 Client Error: Not Found for url: https://vectorbt.pro/pvt_5af3d00f/api/indicators/custom/zigzag/
# Scraping https://vectorbt.pro/pvt_5af3d00f/api/generic/nb/resample/
# Error downloading https://vectorbt.pro/pvt_5af3d00f/api/generic/nb/resample/: 404 Client Error: Not Found for url: https://vectorbt.pro/pvt_5af3d00f/api/generic/nb/resample/
# Scraping https://vectorbt.pro/pvt_5af3d00f/cookbook/
# Scraping https://vectorbt.pro/pvt_5af3d00f/tutorials/pairs-trading
# Scraping https://vectorbt.pro/pvt_5af3d00f/tutorials/signal-development/
# Scraping https://vectorbt.pro/pvt_5af3d00f/api/utils/opt_packages/
# Error downloading https://vectorbt.pro/pvt_5af3d00f/api/utils/opt_packages/: 404 Client Error: Not Found for url: https://vectorbt.pro/pvt_5af3d00f/api/utils/opt_packages/
# Scraping https://vectorbt.pro/pvt_5af3d00f/api/indicators/configs
# Scraping https://vectorbt.pro/pvt_5af3d00f/utils/cutting/
# Error downloading https://vectorbt.pro/pvt_5af3d00f/utils/cutting/: 404 Client Error: Not Found for url: https://vectorbt.pro/pvt_5af3d00f/utils/cutting/
# Scraping https://vectorbt.pro/pvt_5af3d00f/utils/magic_decorators/
# Error downloading https://vectorbt.pro/pvt_5af3d00f/utils/magic_decorators/: 404 Client Error: Not Found for url: https://vectorbt.pro/pvt_5af3d00f/utils/magic_decorators/
# Scraping https://vectorbt.pro/pvt_5af3d00f/records/base/
# Error downloading https://vectorbt.pro/pvt_5af3d00f/records/base/: 404 Client Error: Not Found for url: https://vectorbt.pro/pvt_5af3d00f/records/base/
# Scraping https://vectorbt.pro/pvt_5af3d00f/utils/params/
# Error downloading https://vectorbt.pro/pvt_5af3d00f/utils/params/: 404 Client Error: Not Found for url: https://vectorbt.pro/pvt_5af3d00f/utils/params/
# Scraping https://vectorbt.pro/pvt_5af3d00f/portfolio/decorators/
# Error downloading https://vectorbt.pro/pvt_5af3d00f/portfolio/decorators/: 404 Client Error: Not Found for url: https://vectorbt.pro/pvt_5af3d00f/portfolio/decorators/
# Scraping https://vectorbt.pro/pvt_5af3d00f/signals/enums/
# Error downloading https://vectorbt.pro/pvt_5af3d00f/signals/enums/: 404 Client Error: Not Found for url: https://vectorbt.pro/pvt_5af3d00f/signals/enums/
# Scraping https://vectorbt.pro/pvt_5af3d00f/utils/pickling/
# Error downloading https://vectorbt.pro/pvt_5af3d00f/utils/pickling/: 404 Client Error: Not Found for url: https://vectorbt.pro/pvt_5af3d00f/utils/pickling/
# Scraping https://vectorbt.pro/pvt_5af3d00f/records/mapped_array/
# Error downloading https://vectorbt.pro/pvt_5af3d00f/records/mapped_array/: 404 Client Error: Not Found for url: https://vectorbt.pro/pvt_5af3d00f/records/mapped_array/
# Scraping https://vectorbt.pro/pvt_5af3d00f/utils/array_/
# Error downloading https://vectorbt.pro/pvt_5af3d00f/utils/array_/: 404 Client Error: Not Found for url: https://vectorbt.pro/pvt_5af3d00f/utils/array_/
# Scraping https://vectorbt.pro/pvt_5af3d00f/base/indexing/
# Error downloading https://vectorbt.pro/pvt_5af3d00f/base/indexing/: 404 Client Error: Not Found for url: https://vectorbt.pro/pvt_5af3d00f/base/indexing/
# Scraping https://vectorbt.pro/pvt_5af3d00f/utils/checks/
# Error downloading https://vectorbt.pro/pvt_5af3d00f/utils/checks/: 404 Client Error: Not Found for url: https://vectorbt.pro/pvt_5af3d00f/utils/checks/
# Scraping https://vectorbt.pro/pvt_5af3d00f/records/col_mapper/
# Error downloading https://vectorbt.pro/pvt_5af3d00f/records/col_mapper/: 404 Client Error: Not Found for url: https://vectorbt.pro/pvt_5af3d00f/records/col_mapper/
# Scraping https://vectorbt.pro/pvt_5af3d00f/utils/datetime_/
# Error downloading https://vectorbt.pro/pvt_5af3d00f/utils/datetime_/: 404 Client Error: Not Found for url: https://vectorbt.pro/pvt_5af3d00f/utils/datetime_/
# Scraping https://vectorbt.pro/pvt_5af3d00f/portfolio/pfopt/
# Error downloading https://vectorbt.pro/pvt_5af3d00f/portfolio/pfopt/: 404 Client Error: Not Found for url: https://vectorbt.pro/pvt_5af3d00f/portfolio/pfopt/
# Scraping https://vectorbt.pro/pvt_5af3d00f/base/grouping/
# Error downloading https://vectorbt.pro/pvt_5af3d00f/base/grouping/: 404 Client Error: Not Found for url: https://vectorbt.pro/pvt_5af3d00f/base/grouping/
# Scraping https://vectorbt.pro/pvt_5af3d00f/api/custom/
# Error downloading https://vectorbt.pro/pvt_5af3d00f/api/custom/: 404 Client Error: Not Found for url: https://vectorbt.pro/pvt_5af3d00f/api/custom/
# Scraping https://vectorbt.pro/pvt_5af3d00f/utils/annotations/
# Error downloading https://vectorbt.pro/pvt_5af3d00f/utils/annotations/: 404 Client Error: Not Found for url: https://vectorbt.pro/pvt_5af3d00f/utils/annotations/
# Scraping https://vectorbt.pro/pvt_5af3d00f/ohlcv/accessors/
# Error downloading https://vectorbt.pro/pvt_5af3d00f/ohlcv/accessors/: 404 Client Error: Not Found for url: https://vectorbt.pro/pvt_5af3d00f/ohlcv/accessors/
# Scraping https://vectorbt.pro/pvt_5af3d00f/api/talib_/
# Error downloading https://vectorbt.pro/pvt_5af3d00f/api/talib_/: 404 Client Error: Not Found for url: https://vectorbt.pro/pvt_5af3d00f/api/talib_/
# Scraping https://vectorbt.pro/pvt_5af3d00f/base/decorators/
# Error downloading https://vectorbt.pro/pvt_5af3d00f/base/decorators/: 404 Client Error: Not Found for url: https://vectorbt.pro/pvt_5af3d00f/base/decorators/
# Scraping https://vectorbt.pro/pvt_5af3d00f/utils/math_/
# Error downloading https://vectorbt.pro/pvt_5af3d00f/utils/math_/: 404 Client Error: Not Found for url: https://vectorbt.pro/pvt_5af3d00f/utils/math_/
# Scraping https://vectorbt.pro/pvt_5af3d00f/utils/formatting/
# Error downloading https://vectorbt.pro/pvt_5af3d00f/utils/formatting/: 404 Client Error: Not Found for url: https://vectorbt.pro/pvt_5af3d00f/utils/formatting/
# Scraping https://vectorbt.pro/pvt_5af3d00f/utils/image_/
# Error downloading https://vectorbt.pro/pvt_5af3d00f/utils/image_/: 404 Client Error: Not Found for url: https://vectorbt.pro/pvt_5af3d00f/utils/image_/
# Scraping https://vectorbt.pro/pvt_5af3d00f/_settings/
# Error downloading https://vectorbt.pro/pvt_5af3d00f/_settings/: 404 Client Error: Not Found for url: https://vectorbt.pro/pvt_5af3d00f/_settings/
# Scraping https://vectorbt.pro/pvt_5af3d00f/registries/ca_registry/
# Error downloading https://vectorbt.pro/pvt_5af3d00f/registries/ca_registry/: 404 Client Error: Not Found for url: https://vectorbt.pro/pvt_5af3d00f/registries/ca_registry/
# Scraping https://vectorbt.pro/pvt_5af3d00f/utils/config/
# Error downloading https://vectorbt.pro/pvt_5af3d00f/utils/config/: 404 Client Error: Not Found for url: https://vectorbt.pro/pvt_5af3d00f/utils/config/
# Scraping https://vectorbt.pro/pvt_5af3d00f/portfolio/chunking/
# Error downloading https://vectorbt.pro/pvt_5af3d00f/portfolio/chunking/: 404 Client Error: Not Found for url: https://vectorbt.pro/pvt_5af3d00f/portfolio/chunking/
# Scraping https://vectorbt.pro/pvt_5af3d00f/accessors/
# Error downloading https://vectorbt.pro/pvt_5af3d00f/accessors/: 404 Client Error: Not Found for url: https://vectorbt.pro/pvt_5af3d00f/accessors/
# Scraping https://vectorbt.pro/pvt_5af3d00f/signals/generators/
# Error downloading https://vectorbt.pro/pvt_5af3d00f/signals/generators/: 404 Client Error: Not Found for url: https://vectorbt.pro/pvt_5af3d00f/signals/generators/
# Scraping https://vectorbt.pro/pvt_5af3d00f/labels/generators/
# Error downloading https://vectorbt.pro/pvt_5af3d00f/labels/generators/: 404 Client Error: Not Found for url: https://vectorbt.pro/pvt_5af3d00f/labels/generators/
# Scraping https://vectorbt.pro/pvt_5af3d00f/signals/
# Error downloading https://vectorbt.pro/pvt_5af3d00f/signals/: 404 Client Error: Not Found for url: https://vectorbt.pro/pvt_5af3d00f/signals/
# Scraping https://vectorbt.pro/pvt_5af3d00f/px/accessors/
# Error downloading https://vectorbt.pro/pvt_5af3d00f/px/accessors/: 404 Client Error: Not Found for url: https://vectorbt.pro/pvt_5af3d00f/px/accessors/
# Scraping https://vectorbt.pro/pvt_5af3d00f/base/accessors/
# Error downloading https://vectorbt.pro/pvt_5af3d00f/base/accessors/: 404 Client Error: Not Found for url: https://vectorbt.pro/pvt_5af3d00f/base/accessors/
# Scraping https://vectorbt.pro/pvt_5af3d00f/data/nb/
# Error downloading https://vectorbt.pro/pvt_5af3d00f/data/nb/: 404 Client Error: Not Found for url: https://vectorbt.pro/pvt_5af3d00f/data/nb/
# Scraping https://vectorbt.pro/pvt_5af3d00f/base/reshaping/
# Error downloading https://vectorbt.pro/pvt_5af3d00f/base/reshaping/: 404 Client Error: Not Found for url: https://vectorbt.pro/pvt_5af3d00f/base/reshaping/
# Scraping https://vectorbt.pro/pvt_5af3d00f/portfolio/preparing/
# Error downloading https://vectorbt.pro/pvt_5af3d00f/portfolio/preparing/: 404 Client Error: Not Found for url: https://vectorbt.pro/pvt_5af3d00f/portfolio/preparing/
# Scraping https://vectorbt.pro/pvt_5af3d00f/data/custom/
# Error downloading https://vectorbt.pro/pvt_5af3d00f/data/custom/: 404 Client Error: Not Found for url: https://vectorbt.pro/pvt_5af3d00f/data/custom/
# Scraping https://vectorbt.pro/pvt_5af3d00f/messaging/
# Error downloading https://vectorbt.pro/pvt_5af3d00f/messaging/: 404 Client Error: Not Found for url: https://vectorbt.pro/pvt_5af3d00f/messaging/
# Scraping https://vectorbt.pro/pvt_5af3d00f/generic/nb/
# Error downloading https://vectorbt.pro/pvt_5af3d00f/generic/nb/: 404 Client Error: Not Found for url: https://vectorbt.pro/pvt_5af3d00f/generic/nb/
# Scraping https://vectorbt.pro/pvt_5af3d00f/messaging/telegram/
# Error downloading https://vectorbt.pro/pvt_5af3d00f/messaging/telegram/: 404 Client Error: Not Found for url: https://vectorbt.pro/pvt_5af3d00f/messaging/telegram/
# Scraping https://vectorbt.pro/pvt_5af3d00f/generic/ranges/
# Error downloading https://vectorbt.pro/pvt_5af3d00f/generic/ranges/: 404 Client Error: Not Found for url: https://vectorbt.pro/pvt_5af3d00f/generic/ranges/
# Scraping https://vectorbt.pro/pvt_5af3d00f/utils/chaining/
# Error downloading https://vectorbt.pro/pvt_5af3d00f/utils/chaining/: 404 Client Error: Not Found for url: https://vectorbt.pro/pvt_5af3d00f/utils/chaining/
# Scraping https://vectorbt.pro/pvt_5af3d00f/portfolio/enums/
# Error downloading https://vectorbt.pro/pvt_5af3d00f/portfolio/enums/: 404 Client Error: Not Found for url: https://vectorbt.pro/pvt_5af3d00f/portfolio/enums/
# Scraping https://vectorbt.pro/pvt_5af3d00f/utils/selection/
# Error downloading https://vectorbt.pro/pvt_5af3d00f/utils/selection/: 404 Client Error: Not Found for url: https://vectorbt.pro/pvt_5af3d00f/utils/selection/
# Scraping https://vectorbt.pro/pvt_5af3d00f/generic/plotting/
# Error downloading https://vectorbt.pro/pvt_5af3d00f/generic/plotting/: 404 Client Error: Not Found for url: https://vectorbt.pro/pvt_5af3d00f/generic/plotting/
# Scraping https://vectorbt.pro/pvt_5af3d00f/generic/drawdowns/
# Error downloading https://vectorbt.pro/pvt_5af3d00f/generic/drawdowns/: 404 Client Error: Not Found for url: https://vectorbt.pro/pvt_5af3d00f/generic/drawdowns/
# Scraping https://vectorbt.pro/pvt_5af3d00f/portfolio/nb/
# Error downloading https://vectorbt.pro/pvt_5af3d00f/portfolio/nb/: 404 Client Error: Not Found for url: https://vectorbt.pro/pvt_5af3d00f/portfolio/nb/
# Scraping https://vectorbt.pro/pvt_5af3d00f/utils/colors/
# Error downloading https://vectorbt.pro/pvt_5af3d00f/utils/colors/: 404 Client Error: Not Found for url: https://vectorbt.pro/pvt_5af3d00f/utils/colors/
# Scraping https://vectorbt.pro/pvt_5af3d00f/utils/search/
# Error downloading https://vectorbt.pro/pvt_5af3d00f/utils/search/: 404 Client Error: Not Found for url: https://vectorbt.pro/pvt_5af3d00f/utils/search/
# Scraping https://vectorbt.pro/pvt_5af3d00f/utils/template/
# Error downloading https://vectorbt.pro/pvt_5af3d00f/utils/template/: 404 Client Error: Not Found for url: https://vectorbt.pro/pvt_5af3d00f/utils/template/
# Scraping https://vectorbt.pro/pvt_5af3d00f/data/decorators/
# Error downloading https://vectorbt.pro/pvt_5af3d00f/data/decorators/: 404 Client Error: Not Found for url: https://vectorbt.pro/pvt_5af3d00f/data/decorators/
# Scraping https://vectorbt.pro/pvt_5af3d00f/utils/parsing/
# Error downloading https://vectorbt.pro/pvt_5af3d00f/utils/parsing/: 404 Client Error: Not Found for url: https://vectorbt.pro/pvt_5af3d00f/utils/parsing/
# Scraping https://vectorbt.pro/pvt_5af3d00f/labels/
# Error downloading https://vectorbt.pro/pvt_5af3d00f/labels/: 404 Client Error: Not Found for url: https://vectorbt.pro/pvt_5af3d00f/labels/
# Scraping https://vectorbt.pro/pvt_5af3d00f/records/
# Error downloading https://vectorbt.pro/pvt_5af3d00f/records/: 404 Client Error: Not Found for url: https://vectorbt.pro/pvt_5af3d00f/records/
# Scraping https://vectorbt.pro/pvt_5af3d00f/utils/jitting/
# Error downloading https://vectorbt.pro/pvt_5af3d00f/utils/jitting/: 404 Client Error: Not Found for url: https://vectorbt.pro/pvt_5af3d00f/utils/jitting/
# Scraping https://vectorbt.pro/pvt_5af3d00f/labels/enums/
# Error downloading https://vectorbt.pro/pvt_5af3d00f/labels/enums/: 404 Client Error: Not Found for url: https://vectorbt.pro/pvt_5af3d00f/labels/enums/
# Scraping https://vectorbt.pro/pvt_5af3d00f/portfolio/trades/
# Error downloading https://vectorbt.pro/pvt_5af3d00f/portfolio/trades/: 404 Client Error: Not Found for url: https://vectorbt.pro/pvt_5af3d00f/portfolio/trades/
# Scraping https://vectorbt.pro/pvt_5af3d00f/signals/accessors/
# Error downloading https://vectorbt.pro/pvt_5af3d00f/signals/accessors/: 404 Client Error: Not Found for url: https://vectorbt.pro/pvt_5af3d00f/signals/accessors/
# Scraping https://vectorbt.pro/pvt_5af3d00f/api/factory/
# Error downloading https://vectorbt.pro/pvt_5af3d00f/api/factory/: 404 Client Error: Not Found for url: https://vectorbt.pro/pvt_5af3d00f/api/factory/
# Scraping https://vectorbt.pro/pvt_5af3d00f/data/updater/
# Error downloading https://vectorbt.pro/pvt_5af3d00f/data/updater/: 404 Client Error: Not Found for url: https://vectorbt.pro/pvt_5af3d00f/data/updater/
# Scraping https://vectorbt.pro/pvt_5af3d00f/signals/nb/
# Error downloading https://vectorbt.pro/pvt_5af3d00f/signals/nb/: 404 Client Error: Not Found for url: https://vectorbt.pro/pvt_5af3d00f/signals/nb/
# Scraping https://vectorbt.pro/pvt_5af3d00f/portfolio/base/
# Error downloading https://vectorbt.pro/pvt_5af3d00f/portfolio/base/: 404 Client Error: Not Found for url: https://vectorbt.pro/pvt_5af3d00f/portfolio/base/
# Scraping https://vectorbt.pro/pvt_5af3d00f/utils/eval_/
# Error downloading https://vectorbt.pro/pvt_5af3d00f/utils/eval_/: 404 Client Error: Not Found for url: https://vectorbt.pro/pvt_5af3d00f/utils/eval_/
# Scraping https://vectorbt.pro/pvt_5af3d00f/generic/splitting/
# Error downloading https://vectorbt.pro/pvt_5af3d00f/generic/splitting/: 404 Client Error: Not Found for url: https://vectorbt.pro/pvt_5af3d00f/generic/splitting/
# Scraping https://vectorbt.pro/pvt_5af3d00f/ohlcv/
# Error downloading https://vectorbt.pro/pvt_5af3d00f/ohlcv/: 404 Client Error: Not Found for url: https://vectorbt.pro/pvt_5af3d00f/ohlcv/
# Scraping https://vectorbt.pro/pvt_5af3d00f/utils/module_/
# Error downloading https://vectorbt.pro/pvt_5af3d00f/utils/module_/: 404 Client Error: Not Found for url: https://vectorbt.pro/pvt_5af3d00f/utils/module_/
# Scraping https://vectorbt.pro/pvt_5af3d00f/base/preparing/
# Error downloading https://vectorbt.pro/pvt_5af3d00f/base/preparing/: 404 Client Error: Not Found for url: https://vectorbt.pro/pvt_5af3d00f/base/preparing/
# Scraping https://vectorbt.pro/pvt_5af3d00f/data/base/
# Error downloading https://vectorbt.pro/pvt_5af3d00f/data/base/: 404 Client Error: Not Found for url: https://vectorbt.pro/pvt_5af3d00f/data/base/
# Scraping https://vectorbt.pro/pvt_5af3d00f/returns/qs_adapter/
# Error downloading https://vectorbt.pro/pvt_5af3d00f/returns/qs_adapter/: 404 Client Error: Not Found for url: https://vectorbt.pro/pvt_5af3d00f/returns/qs_adapter/
# Scraping https://vectorbt.pro/pvt_5af3d00f/utils/
# Error downloading https://vectorbt.pro/pvt_5af3d00f/utils/: 404 Client Error: Not Found for url: https://vectorbt.pro/pvt_5af3d00f/utils/
# Scraping https://vectorbt.pro/pvt_5af3d00f/utils/caching/
# Error downloading https://vectorbt.pro/pvt_5af3d00f/utils/caching/: 404 Client Error: Not Found for url: https://vectorbt.pro/pvt_5af3d00f/utils/caching/
# Scraping https://vectorbt.pro/pvt_5af3d00f/utils/requests_/
# Error downloading https://vectorbt.pro/pvt_5af3d00f/utils/requests_/: 404 Client Error: Not Found for url: https://vectorbt.pro/pvt_5af3d00f/utils/requests_/
# Scraping https://vectorbt.pro/pvt_5af3d00f/utils/mapping/
# Error downloading https://vectorbt.pro/pvt_5af3d00f/utils/mapping/: 404 Client Error: Not Found for url: https://vectorbt.pro/pvt_5af3d00f/utils/mapping/
# Scraping https://vectorbt.pro/pvt_5af3d00f/records/decorators/
# Error downloading https://vectorbt.pro/pvt_5af3d00f/records/decorators/: 404 Client Error: Not Found for url: https://vectorbt.pro/pvt_5af3d00f/records/decorators/
# Scraping https://vectorbt.pro/pvt_5af3d00f/px/
# Error downloading https://vectorbt.pro/pvt_5af3d00f/px/: 404 Client Error: Not Found for url: https://vectorbt.pro/pvt_5af3d00f/px/
# Scraping https://vectorbt.pro/pvt_5af3d00f/portfolio/call_seq/
# Error downloading https://vectorbt.pro/pvt_5af3d00f/portfolio/call_seq/: 404 Client Error: Not Found for url: https://vectorbt.pro/pvt_5af3d00f/portfolio/call_seq/
# Scraping https://vectorbt.pro/pvt_5af3d00f/utils/path_/
# Error downloading https://vectorbt.pro/pvt_5af3d00f/utils/path_/: 404 Client Error: Not Found for url: https://vectorbt.pro/pvt_5af3d00f/utils/path_/
# Scraping https://vectorbt.pro/pvt_5af3d00f/utils/random_/
# Error downloading https://vectorbt.pro/pvt_5af3d00f/utils/random_/: 404 Client Error: Not Found for url: https://vectorbt.pro/pvt_5af3d00f/utils/random_/
# Scraping https://vectorbt.pro/pvt_5af3d00f/utils/schedule_/
# Error downloading https://vectorbt.pro/pvt_5af3d00f/utils/schedule_/: 404 Client Error: Not Found for url: https://vectorbt.pro/pvt_5af3d00f/utils/schedule_/
# Scraping https://vectorbt.pro/pvt_5af3d00f/generic/decorators/
# Error downloading https://vectorbt.pro/pvt_5af3d00f/generic/decorators/: 404 Client Error: Not Found for url: https://vectorbt.pro/pvt_5af3d00f/generic/decorators/
# Scraping https://vectorbt.pro/pvt_5af3d00f/utils/figure/
# Error downloading https://vectorbt.pro/pvt_5af3d00f/utils/figure/: 404 Client Error: Not Found for url: https://vectorbt.pro/pvt_5af3d00f/utils/figure/
# Scraping https://vectorbt.pro/pvt_5af3d00f/base/wrapping/
# Error downloading https://vectorbt.pro/pvt_5af3d00f/base/wrapping/: 404 Client Error: Not Found for url: https://vectorbt.pro/pvt_5af3d00f/base/wrapping/
# Scraping https://vectorbt.pro/pvt_5af3d00f/generic/analyzable/
# Error downloading https://vectorbt.pro/pvt_5af3d00f/generic/analyzable/: 404 Client Error: Not Found for url: https://vectorbt.pro/pvt_5af3d00f/generic/analyzable/
# Scraping https://vectorbt.pro/pvt_5af3d00f/utils/pbar/
# Error downloading https://vectorbt.pro/pvt_5af3d00f/utils/pbar/: 404 Client Error: Not Found for url: https://vectorbt.pro/pvt_5af3d00f/utils/pbar/
# Scraping https://vectorbt.pro/pvt_5af3d00f/returns/
# Error downloading https://vectorbt.pro/pvt_5af3d00f/returns/: 404 Client Error: Not Found for url: https://vectorbt.pro/pvt_5af3d00f/returns/
# Scraping https://vectorbt.pro/pvt_5af3d00f/generic/price_records/
# Error downloading https://vectorbt.pro/pvt_5af3d00f/generic/price_records/: 404 Client Error: Not Found for url: https://vectorbt.pro/pvt_5af3d00f/generic/price_records/
# Scraping https://vectorbt.pro/pvt_5af3d00f/utils/decorators/
# Error downloading https://vectorbt.pro/pvt_5af3d00f/utils/decorators/: 404 Client Error: Not Found for url: https://vectorbt.pro/pvt_5af3d00f/utils/decorators/
# Scraping https://vectorbt.pro/pvt_5af3d00f/api/enums/
# Error downloading https://vectorbt.pro/pvt_5af3d00f/api/enums/: 404 Client Error: Not Found for url: https://vectorbt.pro/pvt_5af3d00f/api/enums/
# Scraping https://vectorbt.pro/pvt_5af3d00f/registries/jit_registry/
# Error downloading https://vectorbt.pro/pvt_5af3d00f/registries/jit_registry/: 404 Client Error: Not Found for url: https://vectorbt.pro/pvt_5af3d00f/registries/jit_registry/
# Scraping https://vectorbt.pro/pvt_5af3d00f/generic/accessors/
# Error downloading https://vectorbt.pro/pvt_5af3d00f/generic/accessors/: 404 Client Error: Not Found for url: https://vectorbt.pro/pvt_5af3d00f/generic/accessors/
# Scraping https://vectorbt.pro/pvt_5af3d00f/ohlcv/nb/
# Error downloading https://vectorbt.pro/pvt_5af3d00f/ohlcv/nb/: 404 Client Error: Not Found for url: https://vectorbt.pro/pvt_5af3d00f/ohlcv/nb/
# Scraping https://vectorbt.pro/pvt_5af3d00f/returns/enums/
# Error downloading https://vectorbt.pro/pvt_5af3d00f/returns/enums/: 404 Client Error: Not Found for url: https://vectorbt.pro/pvt_5af3d00f/returns/enums/
# Scraping https://vectorbt.pro/pvt_5af3d00f/signals/factory/
# Error downloading https://vectorbt.pro/pvt_5af3d00f/signals/factory/: 404 Client Error: Not Found for url: https://vectorbt.pro/pvt_5af3d00f/signals/factory/
# Scraping https://vectorbt.pro/pvt_5af3d00f/base/flex_indexing/
# Error downloading https://vectorbt.pro/pvt_5af3d00f/base/flex_indexing/: 404 Client Error: Not Found for url: https://vectorbt.pro/pvt_5af3d00f/base/flex_indexing/
# Scraping https://vectorbt.pro/pvt_5af3d00f/base/combining/
# Error downloading https://vectorbt.pro/pvt_5af3d00f/base/combining/: 404 Client Error: Not Found for url: https://vectorbt.pro/pvt_5af3d00f/base/combining/
# Scraping https://vectorbt.pro/pvt_5af3d00f/portfolio/orders/
# Error downloading https://vectorbt.pro/pvt_5af3d00f/portfolio/orders/: 404 Client Error: Not Found for url: https://vectorbt.pro/pvt_5af3d00f/portfolio/orders/
# Scraping https://vectorbt.pro/pvt_5af3d00f/utils/enum_/
# Error downloading https://vectorbt.pro/pvt_5af3d00f/utils/enum_/: 404 Client Error: Not Found for url: https://vectorbt.pro/pvt_5af3d00f/utils/enum_/
# Scraping https://vectorbt.pro/pvt_5af3d00f/records/nb/
# Error downloading https://vectorbt.pro/pvt_5af3d00f/records/nb/: 404 Client Error: Not Found for url: https://vectorbt.pro/pvt_5af3d00f/records/nb/
# Scraping https://vectorbt.pro/pvt_5af3d00f/_opt_deps/
# Error downloading https://vectorbt.pro/pvt_5af3d00f/_opt_deps/: 404 Client Error: Not Found for url: https://vectorbt.pro/pvt_5af3d00f/_opt_deps/
# Scraping https://vectorbt.pro/pvt_5af3d00f/utils/profiling/
# Error downloading https://vectorbt.pro/pvt_5af3d00f/utils/profiling/: 404 Client Error: Not Found for url: https://vectorbt.pro/pvt_5af3d00f/utils/profiling/
# Scraping https://vectorbt.pro/pvt_5af3d00f/records/chunking/
# Error downloading https://vectorbt.pro/pvt_5af3d00f/records/chunking/: 404 Client Error: Not Found for url: https://vectorbt.pro/pvt_5af3d00f/records/chunking/
# Scraping https://vectorbt.pro/pvt_5af3d00f/utils/hashing/
# Error downloading https://vectorbt.pro/pvt_5af3d00f/utils/hashing/: 404 Client Error: Not Found for url: https://vectorbt.pro/pvt_5af3d00f/utils/hashing/
# Scraping https://vectorbt.pro/pvt_5af3d00f/base/merging/
# Error downloading https://vectorbt.pro/pvt_5af3d00f/base/merging/: 404 Client Error: Not Found for url: https://vectorbt.pro/pvt_5af3d00f/base/merging/
# Scraping https://vectorbt.pro/pvt_5af3d00f/generic/
# Error downloading https://vectorbt.pro/pvt_5af3d00f/generic/: 404 Client Error: Not Found for url: https://vectorbt.pro/pvt_5af3d00f/generic/
# Scraping https://vectorbt.pro/pvt_5af3d00f/utils/merging/
# Error downloading https://vectorbt.pro/pvt_5af3d00f/utils/merging/: 404 Client Error: Not Found for url: https://vectorbt.pro/pvt_5af3d00f/utils/merging/
# Scraping https://vectorbt.pro/pvt_5af3d00f/portfolio/logs/
# Error downloading https://vectorbt.pro/pvt_5af3d00f/portfolio/logs/: 404 Client Error: Not Found for url: https://vectorbt.pro/pvt_5af3d00f/portfolio/logs/
# Scraping https://vectorbt.pro/pvt_5af3d00f/base/resampling/
# Error downloading https://vectorbt.pro/pvt_5af3d00f/base/resampling/: 404 Client Error: Not Found for url: https://vectorbt.pro/pvt_5af3d00f/base/resampling/
# Scraping https://vectorbt.pro/pvt_5af3d00f/utils/tagging/
# Error downloading https://vectorbt.pro/pvt_5af3d00f/utils/tagging/: 404 Client Error: Not Found for url: https://vectorbt.pro/pvt_5af3d00f/utils/tagging/
# Scraping https://vectorbt.pro/pvt_5af3d00f/generic/enums/
# Error downloading https://vectorbt.pro/pvt_5af3d00f/generic/enums/: 404 Client Error: Not Found for url: https://vectorbt.pro/pvt_5af3d00f/generic/enums/
# Scraping https://vectorbt.pro/pvt_5af3d00f/generic/stats_builder/
# Error downloading https://vectorbt.pro/pvt_5af3d00f/generic/stats_builder/: 404 Client Error: Not Found for url: https://vectorbt.pro/pvt_5af3d00f/generic/stats_builder/
# Scraping https://vectorbt.pro/pvt_5af3d00f/returns/accessors/
# Error downloading https://vectorbt.pro/pvt_5af3d00f/returns/accessors/: 404 Client Error: Not Found for url: https://vectorbt.pro/pvt_5af3d00f/returns/accessors/
# Scraping https://vectorbt.pro/pvt_5af3d00f/base/
# Error downloading https://vectorbt.pro/pvt_5af3d00f/base/: 404 Client Error: Not Found for url: https://vectorbt.pro/pvt_5af3d00f/base/
# Scraping https://vectorbt.pro/pvt_5af3d00f/base/indexes/
# Error downloading https://vectorbt.pro/pvt_5af3d00f/base/indexes/: 404 Client Error: Not Found for url: https://vectorbt.pro/pvt_5af3d00f/base/indexes/
# Scraping https://vectorbt.pro/pvt_5af3d00f/utils/datetime_nb/
# Error downloading https://vectorbt.pro/pvt_5af3d00f/utils/datetime_nb/: 404 Client Error: Not Found for url: https://vectorbt.pro/pvt_5af3d00f/utils/datetime_nb/
# Scraping https://vectorbt.pro/pvt_5af3d00f/generic/plots_builder/
# Error downloading https://vectorbt.pro/pvt_5af3d00f/generic/plots_builder/: 404 Client Error: Not Found for url: https://vectorbt.pro/pvt_5af3d00f/generic/plots_builder/
# Scraping https://vectorbt.pro/pvt_5af3d00f/api/expr/
# Error downloading https://vectorbt.pro/pvt_5af3d00f/api/expr/: 404 Client Error: Not Found for url: https://vectorbt.pro/pvt_5af3d00f/api/expr/
# Scraping https://vectorbt.pro/pvt_5af3d00f/data/saver/
# Error downloading https://vectorbt.pro/pvt_5af3d00f/data/saver/: 404 Client Error: Not Found for url: https://vectorbt.pro/pvt_5af3d00f/data/saver/
# Scraping https://vectorbt.pro/pvt_5af3d00f/api/nb/
# Error downloading https://vectorbt.pro/pvt_5af3d00f/api/nb/: 404 Client Error: Not Found for url: https://vectorbt.pro/pvt_5af3d00f/api/nb/
# Scraping https://vectorbt.pro/pvt_5af3d00f/registries/ch_registry/
# Error downloading https://vectorbt.pro/pvt_5af3d00f/registries/ch_registry/: 404 Client Error: Not Found for url: https://vectorbt.pro/pvt_5af3d00f/registries/ch_registry/
# Scraping https://vectorbt.pro/pvt_5af3d00f/utils/chunking/
# Error downloading https://vectorbt.pro/pvt_5af3d00f/utils/chunking/: 404 Client Error: Not Found for url: https://vectorbt.pro/pvt_5af3d00f/utils/chunking/
# Scraping https://vectorbt.pro/pvt_5af3d00f/utils/attr_/
# Error downloading https://vectorbt.pro/pvt_5af3d00f/utils/attr_/: 404 Client Error: Not Found for url: https://vectorbt.pro/pvt_5af3d00f/utils/attr_/
# Scraping https://vectorbt.pro/pvt_5af3d00f/base/chunking/
# Error downloading https://vectorbt.pro/pvt_5af3d00f/base/chunking/: 404 Client Error: Not Found for url: https://vectorbt.pro/pvt_5af3d00f/base/chunking/
# Scraping https://vectorbt.pro/pvt_5af3d00f/registries/
# Error downloading https://vectorbt.pro/pvt_5af3d00f/registries/: 404 Client Error: Not Found for url: https://vectorbt.pro/pvt_5af3d00f/registries/
# Scraping https://vectorbt.pro/pvt_5af3d00f/utils/execution/
# Error downloading https://vectorbt.pro/pvt_5af3d00f/utils/execution/: 404 Client Error: Not Found for url: https://vectorbt.pro/pvt_5af3d00f/utils/execution/
# Scraping https://vectorbt.pro/pvt_5af3d00f/returns/nb/
# Error downloading https://vectorbt.pro/pvt_5af3d00f/returns/nb/: 404 Client Error: Not Found for url: https://vectorbt.pro/pvt_5af3d00f/returns/nb/
# Scraping https://vectorbt.pro/pvt_5af3d00f/labels/nb/
# Error downloading https://vectorbt.pro/pvt_5af3d00f/labels/nb/: 404 Client Error: Not Found for url: https://vectorbt.pro/pvt_5af3d00f/labels/nb/
# Scraping https://vectorbt.pro/pvt_5af3d00f/tutorials/splitter/
# Error downloading https://vectorbt.pro/pvt_5af3d00f/tutorials/splitter/: 404 Client Error: Not Found for url: https://vectorbt.pro/pvt_5af3d00f/tutorials/splitter/
# Scraping https://vectorbt.pro/pvt_5af3d00f/tutorials/applications/
# Error downloading https://vectorbt.pro/pvt_5af3d00f/tutorials/applications/: 404 Client Error: Not Found for url: https://vectorbt.pro/pvt_5af3d00f/tutorials/applications/
# Scraping complete.
